# %%
import spacy
from spacy import displacy

from main_nalir_seade_single_nlq_notebook import *


nlp = spacy.load("pt_core_news_md")

# %%
nlqs = [
    # Sem agregações e sem cláusula 'WHERE'
    "retorne todos os municípios em casos",

    # Sem agregações e com cláusula 'WHERE'
    "retorne todas as idades dos casos onde o município é São Paulo",
    "retorne todas as idades dos casos do município de São Paulo",

    # Agregações sem agrupamentos e sem cláusula 'WHERE'
    "devolva quantos óbitos existem em casos",
    "Devolva quantos casos há",
    "devolva a máxima idade em casos",
    "devolva a mínima idade em casos",
    "devolva as idades somadas em casos",
    "devolva a idade média em casos",

    # Agregações sem agrupamentos e com cláusula 'WHERE'
    "devolva quantos óbitos do tipo positivo existem em casos",
    "devolva quantos óbitos do tipo positivo onde o município é São Paulo",
    "devolva quantos óbitos do tipo positivo há no município de São Paulo",

    "devolva a máxima idade no município de São Paulo",
    "devolva a mínima idade no município de São Paulo",
    "devolva as idades somadas no município de São Paulo",
    "devolva a idade média no município de São Paulo",

    # Agregações com agrupamentos e sem cláusula 'WHERE'
    "devolva quantos casos há por município",
    "devolva a máxima idade por município",
    "devolva a mínima idade por município",
    "devolva as idades somadas por município",
    "devolva a idade média por município",

    # Agregações com agrupamentos e com cláusula 'WHERE'
    "devolva quantos óbitos do tipo positivo há no município de São Paulo por raça",
    "devolva a máxima idade no município de São Paulo por raça",
    "devolva a mínima idade no município de São Paulo por raça",
    "devolva as idades somadas no município de São Paulo por raça",
    "devolva a idade média no município de São Paulo por raça",

    "devolva quantos óbitos do tipo positivo há no município de São Paulo por diagnóstico",
    "devolva quantos diagnóstico há agrupados por raça e por sexo e por diagnóstico",
    "devolva a máxima idade no município de São Paulo por diagnóstico",
    "devolva a mínima idade no município de São Paulo por diagnóstico",
    "devolva as idades somadas no município de São Paulo por diagnóstico",
    "devolva a idade média no município de São Paulo por diagnóstico",
]

# %%
get_sql_command([nlqs[0]])

# %%
doc = nlp(nlqs[0]) 
options = {'compact': False, 'word_spacing': 35, 'distance': 80, 'arrow_spacing': 1, 'arrow_stroke': 1} 
displacy.render(doc, style='dep', page=False, options=options)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="pt" id="cc04db0e230141409f5499ab4d6f927e-0" class="displacy" width="530" height="266.0" direction="ltr" style="max-width: none; height: 266.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="196.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">retorne</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="196.0">
#     <tspan class="displacy-word" fill="currentColor" x="130">todos</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="130">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="196.0">
#     <tspan class="displacy-word" fill="currentColor" x="210">os</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="210">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="196.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">municípios</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="196.0">
#     <tspan class="displacy-word" fill="currentColor" x="370">em</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="370">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="196.0">
#     <tspan class="displacy-word" fill="currentColor" x="450">casos</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="450">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-cc04db0e230141409f5499ab4d6f927e-0-0" stroke-width="1px" d="M131,161.0 C131,81.0 289.5,81.0 289.5,161.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-cc04db0e230141409f5499ab4d6f927e-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M131,163.0 L123,151.0 139,151.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-cc04db0e230141409f5499ab4d6f927e-0-1" stroke-width="1px" d="M131,161.0 C131,121.0 209.25,121.0 209.25,161.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-cc04db0e230141409f5499ab4d6f927e-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">fixed</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M209.25,163.0 L217.25,151.0 201.25,151.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-cc04db0e230141409f5499ab4d6f927e-0-2" stroke-width="1px" d="M51,161.0 C51,41.0 289.75,41.0 289.75,161.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-cc04db0e230141409f5499ab4d6f927e-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">obj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M289.75,163.0 L297.75,151.0 281.75,151.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-cc04db0e230141409f5499ab4d6f927e-0-3" stroke-width="1px" d="M371,161.0 C371,121.0 449.25,121.0 449.25,161.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-cc04db0e230141409f5499ab4d6f927e-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">case</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M371,163.0 L363,151.0 379,151.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-cc04db0e230141409f5499ab4d6f927e-0-4" stroke-width="1px" d="M51,161.0 C51,1.0 450.0,1.0 450.0,161.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-cc04db0e230141409f5499ab4d6f927e-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">obl</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M450.0,163.0 L458.0,151.0 442.0,151.0" fill="currentColor"/>
# </g>
# </svg></span>

# %%
get_sql_command([nlqs[1]])

# %%
doc = nlp(nlqs[1]) 
options = {'compact': False, 'word_spacing': 35, 'distance': 80, 'arrow_spacing': 1, 'arrow_stroke': 1} 
displacy.render(doc, style='dep', page=False, options=options)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="pt" id="c98f241c0ec44c68a7d0a2c2d8cb5d43-0" class="displacy" width="1010" height="266.0" direction="ltr" style="max-width: none; height: 266.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="196.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">retorne</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="196.0">
#     <tspan class="displacy-word" fill="currentColor" x="130">todas</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="130">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="196.0">
#     <tspan class="displacy-word" fill="currentColor" x="210">as</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="210">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="196.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">idades</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="196.0">
#     <tspan class="displacy-word" fill="currentColor" x="370">dos</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="370">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="196.0">
#     <tspan class="displacy-word" fill="currentColor" x="450">casos</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="450">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="196.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">onde</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="196.0">
#     <tspan class="displacy-word" fill="currentColor" x="610">o</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="610">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="196.0">
#     <tspan class="displacy-word" fill="currentColor" x="690">município</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="690">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="196.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">é</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="196.0">
#     <tspan class="displacy-word" fill="currentColor" x="850">São</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="850">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="196.0">
#     <tspan class="displacy-word" fill="currentColor" x="930">Paulo</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="930">PROPN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-c98f241c0ec44c68a7d0a2c2d8cb5d43-0-0" stroke-width="1px" d="M131,161.0 C131,81.0 289.5,81.0 289.5,161.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-c98f241c0ec44c68a7d0a2c2d8cb5d43-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M131,163.0 L123,151.0 139,151.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-c98f241c0ec44c68a7d0a2c2d8cb5d43-0-1" stroke-width="1px" d="M131,161.0 C131,121.0 209.25,121.0 209.25,161.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-c98f241c0ec44c68a7d0a2c2d8cb5d43-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">fixed</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M209.25,163.0 L217.25,151.0 201.25,151.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-c98f241c0ec44c68a7d0a2c2d8cb5d43-0-2" stroke-width="1px" d="M51,161.0 C51,41.0 289.75,41.0 289.75,161.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-c98f241c0ec44c68a7d0a2c2d8cb5d43-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">obj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M289.75,163.0 L297.75,151.0 281.75,151.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-c98f241c0ec44c68a7d0a2c2d8cb5d43-0-3" stroke-width="1px" d="M371,161.0 C371,121.0 449.25,121.0 449.25,161.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-c98f241c0ec44c68a7d0a2c2d8cb5d43-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">case</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M371,163.0 L363,151.0 379,151.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-c98f241c0ec44c68a7d0a2c2d8cb5d43-0-4" stroke-width="1px" d="M291,161.0 C291,81.0 449.5,81.0 449.5,161.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-c98f241c0ec44c68a7d0a2c2d8cb5d43-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M449.5,163.0 L457.5,151.0 441.5,151.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-c98f241c0ec44c68a7d0a2c2d8cb5d43-0-5" stroke-width="1px" d="M531,161.0 C531,41.0 849.75,41.0 849.75,161.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-c98f241c0ec44c68a7d0a2c2d8cb5d43-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M531,163.0 L523,151.0 539,151.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-c98f241c0ec44c68a7d0a2c2d8cb5d43-0-6" stroke-width="1px" d="M611,161.0 C611,121.0 689.25,121.0 689.25,161.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-c98f241c0ec44c68a7d0a2c2d8cb5d43-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M611,163.0 L603,151.0 619,151.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-c98f241c0ec44c68a7d0a2c2d8cb5d43-0-7" stroke-width="1px" d="M691,161.0 C691,81.0 849.5,81.0 849.5,161.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-c98f241c0ec44c68a7d0a2c2d8cb5d43-0-7" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M691,163.0 L683,151.0 699,151.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="a

# %%
get_sql_command([nlqs[2]])

# %%
doc = nlp(nlqs[2]) 
options = {'compact': False, 'word_spacing': 35, 'distance': 80, 'arrow_spacing': 1, 'arrow_stroke': 1} 
displacy.render(doc, style='dep', options=options)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="pt" id="73f260cd20d44e94b92c373236aa2e5d-0" class="displacy" width="930" height="226.0" direction="ltr" style="max-width: none; height: 226.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="156.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">retorne</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="156.0">
#     <tspan class="displacy-word" fill="currentColor" x="130">todas</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="130">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="156.0">
#     <tspan class="displacy-word" fill="currentColor" x="210">as</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="210">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="156.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">idades</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="156.0">
#     <tspan class="displacy-word" fill="currentColor" x="370">dos</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="370">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="156.0">
#     <tspan class="displacy-word" fill="currentColor" x="450">casos</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="450">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="156.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">do</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="156.0">
#     <tspan class="displacy-word" fill="currentColor" x="610">município</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="610">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="156.0">
#     <tspan class="displacy-word" fill="currentColor" x="690">de</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="690">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="156.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">São</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="156.0">
#     <tspan class="displacy-word" fill="currentColor" x="850">Paulo</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="850">PROPN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-73f260cd20d44e94b92c373236aa2e5d-0-0" stroke-width="1px" d="M131,121.0 C131,41.0 289.75,41.0 289.75,121.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-73f260cd20d44e94b92c373236aa2e5d-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M131,123.0 L123,111.0 139,111.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-73f260cd20d44e94b92c373236aa2e5d-0-1" stroke-width="1px" d="M131,121.0 C131,81.0 209.5,81.0 209.5,121.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-73f260cd20d44e94b92c373236aa2e5d-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">fixed</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M209.5,123.0 L217.5,111.0 201.5,111.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-73f260cd20d44e94b92c373236aa2e5d-0-2" stroke-width="1px" d="M51,121.0 C51,1.0 290.0,1.0 290.0,121.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-73f260cd20d44e94b92c373236aa2e5d-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">obj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M290.0,123.0 L298.0,111.0 282.0,111.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-73f260cd20d44e94b92c373236aa2e5d-0-3" stroke-width="1px" d="M371,121.0 C371,81.0 449.5,81.0 449.5,121.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-73f260cd20d44e94b92c373236aa2e5d-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">case</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M371,123.0 L363,111.0 379,111.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-73f260cd20d44e94b92c373236aa2e5d-0-4" stroke-width="1px" d="M291,121.0 C291,41.0 449.75,41.0 449.75,121.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-73f260cd20d44e94b92c373236aa2e5d-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M449.75,123.0 L457.75,111.0 441.75,111.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-73f260cd20d44e94b92c373236aa2e5d-0-5" stroke-width="1px" d="M531,121.0 C531,81.0 609.5,81.0 609.5,121.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-73f260cd20d44e94b92c373236aa2e5d-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">case</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M531,123.0 L523,111.0 539,111.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-73f260cd20d44e94b92c373236aa2e5d-0-6" stroke-width="1px" d="M451,121.0 C451,41.0 609.75,41.0 609.75,121.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-73f260cd20d44e94b92c373236aa2e5d-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M609.75,123.0 L617.75,111.0 601.75,111.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-73f260cd20d44e94b92c373236aa2e5d-0-7" stroke-width="1px" d="M691,121.0 C691,81.0 769.5,81.0 769.5,121.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-73f260cd20d44e94b92c373236aa2e5d-0-7" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">case</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M691,123.0 L683,111.0 699,111.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-73f260cd20d44e94b92c373236aa2e5d-0-8" stroke-width="1px" d="M611,121.0 C611,41.0 769.75,41.0 769.75,121.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arr

# %%
get_sql_command([nlqs[3]])

# %%
doc = nlp(nlqs[3]) 
options = {'compact': False, 'word_spacing': 35, 'distance': 80, 'arrow_spacing': 1, 'arrow_stroke': 1} 
displacy.render(doc, style='dep', options=options)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="pt" id="cdfa1531157c48eda17c7b21bb846a7b-0" class="displacy" width="530" height="226.0" direction="ltr" style="max-width: none; height: 226.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="156.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">devolva</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="156.0">
#     <tspan class="displacy-word" fill="currentColor" x="130">quantos</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="130">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="156.0">
#     <tspan class="displacy-word" fill="currentColor" x="210">óbitos</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="210">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="156.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">existem</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="156.0">
#     <tspan class="displacy-word" fill="currentColor" x="370">em</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="370">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="156.0">
#     <tspan class="displacy-word" fill="currentColor" x="450">casos</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="450">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-cdfa1531157c48eda17c7b21bb846a7b-0-0" stroke-width="1px" d="M131,121.0 C131,81.0 209.5,81.0 209.5,121.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-cdfa1531157c48eda17c7b21bb846a7b-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M131,123.0 L123,111.0 139,111.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-cdfa1531157c48eda17c7b21bb846a7b-0-1" stroke-width="1px" d="M51,121.0 C51,41.0 209.75,41.0 209.75,121.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-cdfa1531157c48eda17c7b21bb846a7b-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">obj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M209.75,123.0 L217.75,111.0 201.75,111.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-cdfa1531157c48eda17c7b21bb846a7b-0-2" stroke-width="1px" d="M51,121.0 C51,1.0 290.0,1.0 290.0,121.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-cdfa1531157c48eda17c7b21bb846a7b-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">ccomp</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M290.0,123.0 L298.0,111.0 282.0,111.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-cdfa1531157c48eda17c7b21bb846a7b-0-3" stroke-width="1px" d="M371,121.0 C371,81.0 449.5,81.0 449.5,121.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-cdfa1531157c48eda17c7b21bb846a7b-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">case</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M371,123.0 L363,111.0 379,111.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-cdfa1531157c48eda17c7b21bb846a7b-0-4" stroke-width="1px" d="M291,121.0 C291,41.0 449.75,41.0 449.75,121.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-cdfa1531157c48eda17c7b21bb846a7b-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">obl</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M449.75,123.0 L457.75,111.0 441.75,111.0" fill="currentColor"/>
# </g>
# </svg></span>

# %%
get_sql_command([nlqs[4]])

# %%
doc = nlp(nlqs[4]) 
options = {'compact': False, 'word_spacing': 35, 'distance': 80, 'arrow_spacing': 1, 'arrow_stroke': 1} 
displacy.render(doc, style='dep', options=options)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="pt" id="82fbfc088a144d34b60f5f13b34716de-0" class="displacy" width="370" height="226.0" direction="ltr" style="max-width: none; height: 226.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="156.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Devolva</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="156.0">
#     <tspan class="displacy-word" fill="currentColor" x="130">quantos</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="130">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="156.0">
#     <tspan class="displacy-word" fill="currentColor" x="210">casos</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="210">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="156.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">há</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">VERB</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-82fbfc088a144d34b60f5f13b34716de-0-0" stroke-width="1px" d="M131,121.0 C131,81.0 209.5,81.0 209.5,121.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-82fbfc088a144d34b60f5f13b34716de-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M131,123.0 L123,111.0 139,111.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-82fbfc088a144d34b60f5f13b34716de-0-1" stroke-width="1px" d="M51,121.0 C51,41.0 209.75,41.0 209.75,121.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-82fbfc088a144d34b60f5f13b34716de-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">obj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M209.75,123.0 L217.75,111.0 201.75,111.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-82fbfc088a144d34b60f5f13b34716de-0-2" stroke-width="1px" d="M51,121.0 C51,1.0 290.0,1.0 290.0,121.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-82fbfc088a144d34b60f5f13b34716de-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">advcl</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M290.0,123.0 L298.0,111.0 282.0,111.0" fill="currentColor"/>
# </g>
# </svg></span>

# %%
get_sql_command([nlqs[5]])

# %%
doc = nlp(nlqs[5]) 
options = {'compact': False, 'word_spacing': 35, 'distance': 80, 'arrow_spacing': 1, 'arrow_stroke': 1} 
displacy.render(doc, style='dep', options=options)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="pt" id="e3a0dff00bd7400c884a7be89400e50a-0" class="displacy" width="530" height="266.0" direction="ltr" style="max-width: none; height: 266.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="196.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">devolva</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="196.0">
#     <tspan class="displacy-word" fill="currentColor" x="130">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="130">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="196.0">
#     <tspan class="displacy-word" fill="currentColor" x="210">máxima</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="210">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="196.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">idade</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="196.0">
#     <tspan class="displacy-word" fill="currentColor" x="370">em</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="370">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="196.0">
#     <tspan class="displacy-word" fill="currentColor" x="450">casos</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="450">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-e3a0dff00bd7400c884a7be89400e50a-0-0" stroke-width="1px" d="M131,161.0 C131,81.0 289.5,81.0 289.5,161.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-e3a0dff00bd7400c884a7be89400e50a-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M131,163.0 L123,151.0 139,151.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-e3a0dff00bd7400c884a7be89400e50a-0-1" stroke-width="1px" d="M211,161.0 C211,121.0 289.25,121.0 289.25,161.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-e3a0dff00bd7400c884a7be89400e50a-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M211,163.0 L203,151.0 219,151.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-e3a0dff00bd7400c884a7be89400e50a-0-2" stroke-width="1px" d="M51,161.0 C51,41.0 289.75,41.0 289.75,161.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-e3a0dff00bd7400c884a7be89400e50a-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">obj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M289.75,163.0 L297.75,151.0 281.75,151.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-e3a0dff00bd7400c884a7be89400e50a-0-3" stroke-width="1px" d="M371,161.0 C371,121.0 449.25,121.0 449.25,161.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-e3a0dff00bd7400c884a7be89400e50a-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">case</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M371,163.0 L363,151.0 379,151.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-e3a0dff00bd7400c884a7be89400e50a-0-4" stroke-width="1px" d="M51,161.0 C51,1.0 450.0,1.0 450.0,161.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-e3a0dff00bd7400c884a7be89400e50a-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">obl</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M450.0,163.0 L458.0,151.0 442.0,151.0" fill="currentColor"/>
# </g>
# </svg></span>

# %%
get_sql_command([nlqs[6]])

# %%
doc = nlp(nlqs[6]) 
options = {'compact': False, 'word_spacing': 35, 'distance': 80, 'arrow_spacing': 1, 'arrow_stroke': 1} 
displacy.render(doc, style='dep', options=options)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="pt" id="1d9a3ffde27f457688e99694a1e9b1c1-0" class="displacy" width="530" height="266.0" direction="ltr" style="max-width: none; height: 266.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="196.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">devolva</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="196.0">
#     <tspan class="displacy-word" fill="currentColor" x="130">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="130">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="196.0">
#     <tspan class="displacy-word" fill="currentColor" x="210">mínima</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="210">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="196.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">idade</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="196.0">
#     <tspan class="displacy-word" fill="currentColor" x="370">em</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="370">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="196.0">
#     <tspan class="displacy-word" fill="currentColor" x="450">casos</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="450">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-1d9a3ffde27f457688e99694a1e9b1c1-0-0" stroke-width="1px" d="M131,161.0 C131,81.0 289.5,81.0 289.5,161.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-1d9a3ffde27f457688e99694a1e9b1c1-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">case</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M131,163.0 L123,151.0 139,151.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-1d9a3ffde27f457688e99694a1e9b1c1-0-1" stroke-width="1px" d="M211,161.0 C211,121.0 289.25,121.0 289.25,161.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-1d9a3ffde27f457688e99694a1e9b1c1-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M211,163.0 L203,151.0 219,151.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-1d9a3ffde27f457688e99694a1e9b1c1-0-2" stroke-width="1px" d="M51,161.0 C51,41.0 289.75,41.0 289.75,161.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-1d9a3ffde27f457688e99694a1e9b1c1-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">obj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M289.75,163.0 L297.75,151.0 281.75,151.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-1d9a3ffde27f457688e99694a1e9b1c1-0-3" stroke-width="1px" d="M371,161.0 C371,121.0 449.25,121.0 449.25,161.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-1d9a3ffde27f457688e99694a1e9b1c1-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">case</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M371,163.0 L363,151.0 379,151.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-1d9a3ffde27f457688e99694a1e9b1c1-0-4" stroke-width="1px" d="M51,161.0 C51,1.0 450.0,1.0 450.0,161.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-1d9a3ffde27f457688e99694a1e9b1c1-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">obl</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M450.0,163.0 L458.0,151.0 442.0,151.0" fill="currentColor"/>
# </g>
# </svg></span>

# %%
get_sql_command([nlqs[7]])

# %%
doc = nlp(nlqs[7]) 
options = {'compact': False, 'word_spacing': 35, 'distance': 80, 'arrow_spacing': 1, 'arrow_stroke': 1} 
displacy.render(doc, style='dep', options=options)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="pt" id="b436abe2aca54c56aa17532cf15af15d-0" class="displacy" width="530" height="186.0" direction="ltr" style="max-width: none; height: 186.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="116.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">devolva</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="116.0">
#     <tspan class="displacy-word" fill="currentColor" x="130">as</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="130">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="116.0">
#     <tspan class="displacy-word" fill="currentColor" x="210">idades</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="210">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="116.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">somadas</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="116.0">
#     <tspan class="displacy-word" fill="currentColor" x="370">em</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="370">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="116.0">
#     <tspan class="displacy-word" fill="currentColor" x="450">casos</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="450">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b436abe2aca54c56aa17532cf15af15d-0-0" stroke-width="1px" d="M131,81.0 C131,41.0 209.75,41.0 209.75,81.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b436abe2aca54c56aa17532cf15af15d-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M131,83.0 L123,71.0 139,71.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b436abe2aca54c56aa17532cf15af15d-0-1" stroke-width="1px" d="M51,81.0 C51,1.0 210.0,1.0 210.0,81.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b436abe2aca54c56aa17532cf15af15d-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">obj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M210.0,83.0 L218.0,71.0 202.0,71.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b436abe2aca54c56aa17532cf15af15d-0-2" stroke-width="1px" d="M211,81.0 C211,41.0 289.75,41.0 289.75,81.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b436abe2aca54c56aa17532cf15af15d-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">acl</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M289.75,83.0 L297.75,71.0 281.75,71.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b436abe2aca54c56aa17532cf15af15d-0-3" stroke-width="1px" d="M371,81.0 C371,41.0 449.75,41.0 449.75,81.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b436abe2aca54c56aa17532cf15af15d-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">case</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M371,83.0 L363,71.0 379,71.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b436abe2aca54c56aa17532cf15af15d-0-4" stroke-width="1px" d="M291,81.0 C291,1.0 450.0,1.0 450.0,81.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b436abe2aca54c56aa17532cf15af15d-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">obl</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M450.0,83.0 L458.0,71.0 442.0,71.0" fill="currentColor"/>
# </g>
# </svg></span>

# %%
get_sql_command([nlqs[8]])

# %%
doc = nlp(nlqs[8]) 
options = {'compact': False, 'word_spacing': 35, 'distance': 80, 'arrow_spacing': 1, 'arrow_stroke': 1} 
displacy.render(doc, style='dep', options=options)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="pt" id="e691e570d0bb494eb01da699aa8e8f18-0" class="displacy" width="530" height="226.0" direction="ltr" style="max-width: none; height: 226.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="156.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">devolva</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="156.0">
#     <tspan class="displacy-word" fill="currentColor" x="130">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="130">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="156.0">
#     <tspan class="displacy-word" fill="currentColor" x="210">idade</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="210">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="156.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">média</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="156.0">
#     <tspan class="displacy-word" fill="currentColor" x="370">em</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="370">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="156.0">
#     <tspan class="displacy-word" fill="currentColor" x="450">casos</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="450">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-e691e570d0bb494eb01da699aa8e8f18-0-0" stroke-width="1px" d="M131,121.0 C131,81.0 209.5,81.0 209.5,121.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-e691e570d0bb494eb01da699aa8e8f18-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M131,123.0 L123,111.0 139,111.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-e691e570d0bb494eb01da699aa8e8f18-0-1" stroke-width="1px" d="M51,121.0 C51,41.0 209.75,41.0 209.75,121.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-e691e570d0bb494eb01da699aa8e8f18-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">obj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M209.75,123.0 L217.75,111.0 201.75,111.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-e691e570d0bb494eb01da699aa8e8f18-0-2" stroke-width="1px" d="M211,121.0 C211,81.0 289.5,81.0 289.5,121.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-e691e570d0bb494eb01da699aa8e8f18-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M289.5,123.0 L297.5,111.0 281.5,111.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-e691e570d0bb494eb01da699aa8e8f18-0-3" stroke-width="1px" d="M371,121.0 C371,81.0 449.5,81.0 449.5,121.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-e691e570d0bb494eb01da699aa8e8f18-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">case</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M371,123.0 L363,111.0 379,111.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-e691e570d0bb494eb01da699aa8e8f18-0-4" stroke-width="1px" d="M51,121.0 C51,1.0 450.0,1.0 450.0,121.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-e691e570d0bb494eb01da699aa8e8f18-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">obl</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M450.0,123.0 L458.0,111.0 442.0,111.0" fill="currentColor"/>
# </g>
# </svg></span>

# %%
get_sql_command([nlqs[9]])

# %%
doc = nlp(nlqs[9]) 
options = {'compact': False, 'word_spacing': 35, 'distance': 80, 'arrow_spacing': 1, 'arrow_stroke': 1} 
displacy.render(doc, style='dep', options=options)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="pt" id="6ee9f3b3eaae46ed9daf86588e361150-0" class="displacy" width="770" height="226.0" direction="ltr" style="max-width: none; height: 226.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="156.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">devolva</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="156.0">
#     <tspan class="displacy-word" fill="currentColor" x="130">quantos</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="130">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="156.0">
#     <tspan class="displacy-word" fill="currentColor" x="210">óbitos</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="210">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="156.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">do</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="156.0">
#     <tspan class="displacy-word" fill="currentColor" x="370">tipo</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="370">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="156.0">
#     <tspan class="displacy-word" fill="currentColor" x="450">positivo</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="450">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="156.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">existem</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="156.0">
#     <tspan class="displacy-word" fill="currentColor" x="610">em</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="610">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="156.0">
#     <tspan class="displacy-word" fill="currentColor" x="690">casos</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="690">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-6ee9f3b3eaae46ed9daf86588e361150-0-0" stroke-width="1px" d="M131,121.0 C131,81.0 209.5,81.0 209.5,121.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-6ee9f3b3eaae46ed9daf86588e361150-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M131,123.0 L123,111.0 139,111.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-6ee9f3b3eaae46ed9daf86588e361150-0-1" stroke-width="1px" d="M51,121.0 C51,41.0 209.75,41.0 209.75,121.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-6ee9f3b3eaae46ed9daf86588e361150-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">obj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M209.75,123.0 L217.75,111.0 201.75,111.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-6ee9f3b3eaae46ed9daf86588e361150-0-2" stroke-width="1px" d="M291,121.0 C291,81.0 369.5,81.0 369.5,121.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-6ee9f3b3eaae46ed9daf86588e361150-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">case</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M291,123.0 L283,111.0 299,111.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-6ee9f3b3eaae46ed9daf86588e361150-0-3" stroke-width="1px" d="M211,121.0 C211,41.0 369.75,41.0 369.75,121.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-6ee9f3b3eaae46ed9daf86588e361150-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M369.75,123.0 L377.75,111.0 361.75,111.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-6ee9f3b3eaae46ed9daf86588e361150-0-4" stroke-width="1px" d="M371,121.0 C371,81.0 449.5,81.0 449.5,121.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-6ee9f3b3eaae46ed9daf86588e361150-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M449.5,123.0 L457.5,111.0 441.5,111.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-6ee9f3b3eaae46ed9daf86588e361150-0-5" stroke-width="1px" d="M51,121.0 C51,1.0 530.0,1.0 530.0,121.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-6ee9f3b3eaae46ed9daf86588e361150-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">ccomp</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M530.0,123.0 L538.0,111.0 522.0,111.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-6ee9f3b3eaae46ed9daf86588e361150-0-6" stroke-width="1px" d="M611,121.0 C611,81.0 689.5,81.0 689.5,121.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-6ee9f3b3eaae46ed9daf86588e361150-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">case</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M611,123.0 L603,111.0 619,111.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-6ee9f3b3eaae46ed9daf86588e361150-0-7" stroke-width="1px" d="M531,121.0 C531,41.0 689.75,41.0 689.75,121.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-6ee9f3b3eaae46ed9daf86588e361150-0-7" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">obl</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M689.75,123.0 L697.75,111.0 681.75,111.0" fill="currentColor"/>
# </g>
# </svg></span>

# %%
get_sql_command([nlqs[10]])

# %%
doc = nlp(nlqs[10]) 
options = {'compact': False, 'word_spacing': 35, 'distance': 80, 'arrow_spacing': 1, 'arrow_stroke': 1} 
displacy.render(doc, style='dep', options=options)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="pt" id="b09a43577e4a4e6f80e423474b4f81e1-0" class="displacy" width="1010" height="266.0" direction="ltr" style="max-width: none; height: 266.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="196.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">devolva</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="196.0">
#     <tspan class="displacy-word" fill="currentColor" x="130">quantos</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="130">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="196.0">
#     <tspan class="displacy-word" fill="currentColor" x="210">óbitos</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="210">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="196.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">do</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="196.0">
#     <tspan class="displacy-word" fill="currentColor" x="370">tipo</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="370">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="196.0">
#     <tspan class="displacy-word" fill="currentColor" x="450">positivo</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="450">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="196.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">onde</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="196.0">
#     <tspan class="displacy-word" fill="currentColor" x="610">o</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="610">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="196.0">
#     <tspan class="displacy-word" fill="currentColor" x="690">município</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="690">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="196.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">é</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="196.0">
#     <tspan class="displacy-word" fill="currentColor" x="850">São</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="850">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="196.0">
#     <tspan class="displacy-word" fill="currentColor" x="930">Paulo</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="930">PROPN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b09a43577e4a4e6f80e423474b4f81e1-0-0" stroke-width="1px" d="M131,161.0 C131,121.0 209.25,121.0 209.25,161.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b09a43577e4a4e6f80e423474b4f81e1-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M131,163.0 L123,151.0 139,151.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b09a43577e4a4e6f80e423474b4f81e1-0-1" stroke-width="1px" d="M51,161.0 C51,81.0 209.5,81.0 209.5,161.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b09a43577e4a4e6f80e423474b4f81e1-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">obj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M209.5,163.0 L217.5,151.0 201.5,151.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b09a43577e4a4e6f80e423474b4f81e1-0-2" stroke-width="1px" d="M291,161.0 C291,121.0 369.25,121.0 369.25,161.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b09a43577e4a4e6f80e423474b4f81e1-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">case</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M291,163.0 L283,151.0 299,151.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b09a43577e4a4e6f80e423474b4f81e1-0-3" stroke-width="1px" d="M211,161.0 C211,81.0 369.5,81.0 369.5,161.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b09a43577e4a4e6f80e423474b4f81e1-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M369.5,163.0 L377.5,151.0 361.5,151.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b09a43577e4a4e6f80e423474b4f81e1-0-4" stroke-width="1px" d="M371,161.0 C371,121.0 449.25,121.0 449.25,161.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b09a43577e4a4e6f80e423474b4f81e1-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M449.25,163.0 L457.25,151.0 441.25,151.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b09a43577e4a4e6f80e423474b4f81e1-0-5" stroke-width="1px" d="M531,161.0 C531,41.0 849.75,41.0 849.75,161.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b09a43577e4a4e6f80e423474b4f81e1-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">obl</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M531,163.0 L523,151.0 539,151.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b09a43577e4a4e6f80e423474b4f81e1-0-6" stroke-width="1px" d="M611,161.0 C611,121.0 689.25,121.0 689.25,161.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b09a43577e4a4e6f80e423474b4f81e1-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M611,163.0 L603,151.0 619,151.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b09a43577e4a4e6f80e423474b4f81e1-0-7" stroke-width="1px" d="M691,161.0 C691,81.0 849.5,81.0 849.5,161.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b09a43577e4a4e6f80e423474b4f81e1-0-7" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M691,163.0 L683,151.0 699,151.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id

# %%
get_sql_command([nlqs[11]])

# %%
doc = nlp(nlqs[11]) 
options = {'compact': False, 'word_spacing': 35, 'distance': 80, 'arrow_spacing': 1, 'arrow_stroke': 1} 
displacy.render(doc, style='dep', options=options)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="pt" id="e1f31e3510624da4961891b0ee057565-0" class="displacy" width="1010" height="226.0" direction="ltr" style="max-width: none; height: 226.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="156.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">devolva</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="156.0">
#     <tspan class="displacy-word" fill="currentColor" x="130">quantos</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="130">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="156.0">
#     <tspan class="displacy-word" fill="currentColor" x="210">óbitos</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="210">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="156.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">do</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="156.0">
#     <tspan class="displacy-word" fill="currentColor" x="370">tipo</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="370">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="156.0">
#     <tspan class="displacy-word" fill="currentColor" x="450">positivo</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="450">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="156.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">há</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="156.0">
#     <tspan class="displacy-word" fill="currentColor" x="610">no</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="610">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="156.0">
#     <tspan class="displacy-word" fill="currentColor" x="690">município</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="690">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="156.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">de</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="156.0">
#     <tspan class="displacy-word" fill="currentColor" x="850">São</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="850">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="156.0">
#     <tspan class="displacy-word" fill="currentColor" x="930">Paulo</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="930">PROPN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-e1f31e3510624da4961891b0ee057565-0-0" stroke-width="1px" d="M131,121.0 C131,81.0 209.5,81.0 209.5,121.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-e1f31e3510624da4961891b0ee057565-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M131,123.0 L123,111.0 139,111.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-e1f31e3510624da4961891b0ee057565-0-1" stroke-width="1px" d="M51,121.0 C51,41.0 209.75,41.0 209.75,121.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-e1f31e3510624da4961891b0ee057565-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">obj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M209.75,123.0 L217.75,111.0 201.75,111.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-e1f31e3510624da4961891b0ee057565-0-2" stroke-width="1px" d="M291,121.0 C291,81.0 369.5,81.0 369.5,121.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-e1f31e3510624da4961891b0ee057565-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">case</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M291,123.0 L283,111.0 299,111.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-e1f31e3510624da4961891b0ee057565-0-3" stroke-width="1px" d="M211,121.0 C211,41.0 369.75,41.0 369.75,121.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-e1f31e3510624da4961891b0ee057565-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M369.75,123.0 L377.75,111.0 361.75,111.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-e1f31e3510624da4961891b0ee057565-0-4" stroke-width="1px" d="M371,121.0 C371,81.0 449.5,81.0 449.5,121.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-e1f31e3510624da4961891b0ee057565-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M449.5,123.0 L457.5,111.0 441.5,111.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-e1f31e3510624da4961891b0ee057565-0-5" stroke-width="1px" d="M51,121.0 C51,1.0 530.0,1.0 530.0,121.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-e1f31e3510624da4961891b0ee057565-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">advcl</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M530.0,123.0 L538.0,111.0 522.0,111.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-e1f31e3510624da4961891b0ee057565-0-6" stroke-width="1px" d="M611,121.0 C611,81.0 689.5,81.0 689.5,121.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-e1f31e3510624da4961891b0ee057565-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">case</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M611,123.0 L603,111.0 619,111.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-e1f31e3510624da4961891b0ee057565-0-7" stroke-width="1px" d="M531,121.0 C531,41.0 689.75,41.0 689.75,121.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-e1f31e3510624da4961891b0ee057565-0-7" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">obl</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M689.75,123.0 L697.75,111.0 681.75,111.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc"

# %%
get_sql_command([nlqs[12]])

# %%
doc = nlp(nlqs[12]) 
options = {'compact': False, 'word_spacing': 35, 'distance': 80, 'arrow_spacing': 1, 'arrow_stroke': 1} 
displacy.render(doc, style='dep', options=options)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="pt" id="b06ac44222334ec58ff29c0dd73abf84-0" class="displacy" width="770" height="266.0" direction="ltr" style="max-width: none; height: 266.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="196.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">devolva</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="196.0">
#     <tspan class="displacy-word" fill="currentColor" x="130">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="130">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="196.0">
#     <tspan class="displacy-word" fill="currentColor" x="210">máxima</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="210">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="196.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">idade</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="196.0">
#     <tspan class="displacy-word" fill="currentColor" x="370">no</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="370">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="196.0">
#     <tspan class="displacy-word" fill="currentColor" x="450">município</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="450">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="196.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">de</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="196.0">
#     <tspan class="displacy-word" fill="currentColor" x="610">São</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="610">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="196.0">
#     <tspan class="displacy-word" fill="currentColor" x="690">Paulo</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="690">PROPN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b06ac44222334ec58ff29c0dd73abf84-0-0" stroke-width="1px" d="M131,161.0 C131,81.0 289.5,81.0 289.5,161.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b06ac44222334ec58ff29c0dd73abf84-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M131,163.0 L123,151.0 139,151.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b06ac44222334ec58ff29c0dd73abf84-0-1" stroke-width="1px" d="M211,161.0 C211,121.0 289.25,121.0 289.25,161.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b06ac44222334ec58ff29c0dd73abf84-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M211,163.0 L203,151.0 219,151.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b06ac44222334ec58ff29c0dd73abf84-0-2" stroke-width="1px" d="M51,161.0 C51,41.0 289.75,41.0 289.75,161.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b06ac44222334ec58ff29c0dd73abf84-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">obj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M289.75,163.0 L297.75,151.0 281.75,151.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b06ac44222334ec58ff29c0dd73abf84-0-3" stroke-width="1px" d="M371,161.0 C371,121.0 449.25,121.0 449.25,161.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b06ac44222334ec58ff29c0dd73abf84-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">case</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M371,163.0 L363,151.0 379,151.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b06ac44222334ec58ff29c0dd73abf84-0-4" stroke-width="1px" d="M51,161.0 C51,1.0 450.0,1.0 450.0,161.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b06ac44222334ec58ff29c0dd73abf84-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">obl</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M450.0,163.0 L458.0,151.0 442.0,151.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b06ac44222334ec58ff29c0dd73abf84-0-5" stroke-width="1px" d="M531,161.0 C531,121.0 609.25,121.0 609.25,161.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b06ac44222334ec58ff29c0dd73abf84-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">case</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M531,163.0 L523,151.0 539,151.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b06ac44222334ec58ff29c0dd73abf84-0-6" stroke-width="1px" d="M451,161.0 C451,81.0 609.5,81.0 609.5,161.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b06ac44222334ec58ff29c0dd73abf84-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M609.5,163.0 L617.5,151.0 601.5,151.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b06ac44222334ec58ff29c0dd73abf84-0-7" stroke-width="1px" d="M611,161.0 C611,121.0 689.25,121.0 689.25,161.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b06ac44222334ec58ff29c0dd73abf84-0-7" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">flat:name</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M689.25,163.0 L697.25,151.0 681.25,151.0" fill="currentColor"/>
# </g>
# </svg></span>

# %%
get_sql_command([nlqs[13]])

# %%
doc = nlp(nlqs[13]) 
options = {'compact': False, 'word_spacing': 35, 'distance': 80, 'arrow_spacing': 1, 'arrow_stroke': 1} 
displacy.render(doc, style='dep', options=options)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="pt" id="f5fe2492372246789eec34af5b08e8a9-0" class="displacy" width="770" height="266.0" direction="ltr" style="max-width: none; height: 266.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="196.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">devolva</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="196.0">
#     <tspan class="displacy-word" fill="currentColor" x="130">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="130">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="196.0">
#     <tspan class="displacy-word" fill="currentColor" x="210">mínima</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="210">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="196.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">idade</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="196.0">
#     <tspan class="displacy-word" fill="currentColor" x="370">no</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="370">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="196.0">
#     <tspan class="displacy-word" fill="currentColor" x="450">município</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="450">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="196.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">de</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="196.0">
#     <tspan class="displacy-word" fill="currentColor" x="610">São</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="610">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="196.0">
#     <tspan class="displacy-word" fill="currentColor" x="690">Paulo</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="690">PROPN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-f5fe2492372246789eec34af5b08e8a9-0-0" stroke-width="1px" d="M131,161.0 C131,81.0 289.5,81.0 289.5,161.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-f5fe2492372246789eec34af5b08e8a9-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">case</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M131,163.0 L123,151.0 139,151.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-f5fe2492372246789eec34af5b08e8a9-0-1" stroke-width="1px" d="M211,161.0 C211,121.0 289.25,121.0 289.25,161.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-f5fe2492372246789eec34af5b08e8a9-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M211,163.0 L203,151.0 219,151.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-f5fe2492372246789eec34af5b08e8a9-0-2" stroke-width="1px" d="M51,161.0 C51,41.0 289.75,41.0 289.75,161.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-f5fe2492372246789eec34af5b08e8a9-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">obj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M289.75,163.0 L297.75,151.0 281.75,151.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-f5fe2492372246789eec34af5b08e8a9-0-3" stroke-width="1px" d="M371,161.0 C371,121.0 449.25,121.0 449.25,161.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-f5fe2492372246789eec34af5b08e8a9-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">case</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M371,163.0 L363,151.0 379,151.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-f5fe2492372246789eec34af5b08e8a9-0-4" stroke-width="1px" d="M51,161.0 C51,1.0 450.0,1.0 450.0,161.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-f5fe2492372246789eec34af5b08e8a9-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">obl</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M450.0,163.0 L458.0,151.0 442.0,151.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-f5fe2492372246789eec34af5b08e8a9-0-5" stroke-width="1px" d="M531,161.0 C531,121.0 609.25,121.0 609.25,161.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-f5fe2492372246789eec34af5b08e8a9-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">case</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M531,163.0 L523,151.0 539,151.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-f5fe2492372246789eec34af5b08e8a9-0-6" stroke-width="1px" d="M451,161.0 C451,81.0 609.5,81.0 609.5,161.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-f5fe2492372246789eec34af5b08e8a9-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M609.5,163.0 L617.5,151.0 601.5,151.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-f5fe2492372246789eec34af5b08e8a9-0-7" stroke-width="1px" d="M611,161.0 C611,121.0 689.25,121.0 689.25,161.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-f5fe2492372246789eec34af5b08e8a9-0-7" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">flat:name</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M689.25,163.0 L697.25,151.0 681.25,151.0" fill="currentColor"/>
# </g>
# </svg></span>

# %%
get_sql_command([nlqs[14]])

# %%
doc = nlp(nlqs[14]) 
options = {'compact': False, 'word_spacing': 35, 'distance': 80, 'arrow_spacing': 1, 'arrow_stroke': 1} 
displacy.render(doc, style='dep', options=options)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="pt" id="b1081b391f2d458988b857fc050d3698-0" class="displacy" width="770" height="186.0" direction="ltr" style="max-width: none; height: 186.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="116.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">devolva</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="116.0">
#     <tspan class="displacy-word" fill="currentColor" x="130">as</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="130">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="116.0">
#     <tspan class="displacy-word" fill="currentColor" x="210">idades</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="210">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="116.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">somadas</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="116.0">
#     <tspan class="displacy-word" fill="currentColor" x="370">no</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="370">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="116.0">
#     <tspan class="displacy-word" fill="currentColor" x="450">município</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="450">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="116.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">de</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="116.0">
#     <tspan class="displacy-word" fill="currentColor" x="610">São</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="610">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="116.0">
#     <tspan class="displacy-word" fill="currentColor" x="690">Paulo</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="690">PROPN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b1081b391f2d458988b857fc050d3698-0-0" stroke-width="1px" d="M131,81.0 C131,41.0 209.75,41.0 209.75,81.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b1081b391f2d458988b857fc050d3698-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M131,83.0 L123,71.0 139,71.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b1081b391f2d458988b857fc050d3698-0-1" stroke-width="1px" d="M51,81.0 C51,1.0 210.0,1.0 210.0,81.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b1081b391f2d458988b857fc050d3698-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">obj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M210.0,83.0 L218.0,71.0 202.0,71.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b1081b391f2d458988b857fc050d3698-0-2" stroke-width="1px" d="M211,81.0 C211,41.0 289.75,41.0 289.75,81.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b1081b391f2d458988b857fc050d3698-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">acl</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M289.75,83.0 L297.75,71.0 281.75,71.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b1081b391f2d458988b857fc050d3698-0-3" stroke-width="1px" d="M371,81.0 C371,41.0 449.75,41.0 449.75,81.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b1081b391f2d458988b857fc050d3698-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">case</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M371,83.0 L363,71.0 379,71.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b1081b391f2d458988b857fc050d3698-0-4" stroke-width="1px" d="M291,81.0 C291,1.0 450.0,1.0 450.0,81.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b1081b391f2d458988b857fc050d3698-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">obl</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M450.0,83.0 L458.0,71.0 442.0,71.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b1081b391f2d458988b857fc050d3698-0-5" stroke-width="1px" d="M531,81.0 C531,41.0 609.75,41.0 609.75,81.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b1081b391f2d458988b857fc050d3698-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">case</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M531,83.0 L523,71.0 539,71.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b1081b391f2d458988b857fc050d3698-0-6" stroke-width="1px" d="M451,81.0 C451,1.0 610.0,1.0 610.0,81.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b1081b391f2d458988b857fc050d3698-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M610.0,83.0 L618.0,71.0 602.0,71.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b1081b391f2d458988b857fc050d3698-0-7" stroke-width="1px" d="M611,81.0 C611,41.0 689.75,41.0 689.75,81.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b1081b391f2d458988b857fc050d3698-0-7" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">flat:name</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M689.75,83.0 L697.75,71.0 681.75,71.0" fill="currentColor"/>
# </g>
# </svg></span>

# %%
get_sql_command([nlqs[15]])

# %%
doc = nlp(nlqs[15]) 
options = {'compact': False, 'word_spacing': 35, 'distance': 80, 'arrow_spacing': 1, 'arrow_stroke': 1} 
displacy.render(doc, style='dep', options=options)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="pt" id="4b5ae123747f497d8b6871de1246846e-0" class="displacy" width="770" height="226.0" direction="ltr" style="max-width: none; height: 226.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="156.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">devolva</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="156.0">
#     <tspan class="displacy-word" fill="currentColor" x="130">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="130">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="156.0">
#     <tspan class="displacy-word" fill="currentColor" x="210">idade</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="210">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="156.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">média</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="156.0">
#     <tspan class="displacy-word" fill="currentColor" x="370">no</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="370">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="156.0">
#     <tspan class="displacy-word" fill="currentColor" x="450">município</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="450">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="156.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">de</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="156.0">
#     <tspan class="displacy-word" fill="currentColor" x="610">São</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="610">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="156.0">
#     <tspan class="displacy-word" fill="currentColor" x="690">Paulo</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="690">PROPN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-4b5ae123747f497d8b6871de1246846e-0-0" stroke-width="1px" d="M131,121.0 C131,81.0 209.5,81.0 209.5,121.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-4b5ae123747f497d8b6871de1246846e-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M131,123.0 L123,111.0 139,111.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-4b5ae123747f497d8b6871de1246846e-0-1" stroke-width="1px" d="M51,121.0 C51,41.0 209.75,41.0 209.75,121.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-4b5ae123747f497d8b6871de1246846e-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">obj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M209.75,123.0 L217.75,111.0 201.75,111.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-4b5ae123747f497d8b6871de1246846e-0-2" stroke-width="1px" d="M211,121.0 C211,81.0 289.5,81.0 289.5,121.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-4b5ae123747f497d8b6871de1246846e-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M289.5,123.0 L297.5,111.0 281.5,111.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-4b5ae123747f497d8b6871de1246846e-0-3" stroke-width="1px" d="M371,121.0 C371,81.0 449.5,81.0 449.5,121.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-4b5ae123747f497d8b6871de1246846e-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">case</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M371,123.0 L363,111.0 379,111.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-4b5ae123747f497d8b6871de1246846e-0-4" stroke-width="1px" d="M51,121.0 C51,1.0 450.0,1.0 450.0,121.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-4b5ae123747f497d8b6871de1246846e-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">obl</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M450.0,123.0 L458.0,111.0 442.0,111.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-4b5ae123747f497d8b6871de1246846e-0-5" stroke-width="1px" d="M531,121.0 C531,81.0 609.5,81.0 609.5,121.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-4b5ae123747f497d8b6871de1246846e-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">case</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M531,123.0 L523,111.0 539,111.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-4b5ae123747f497d8b6871de1246846e-0-6" stroke-width="1px" d="M451,121.0 C451,41.0 609.75,41.0 609.75,121.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-4b5ae123747f497d8b6871de1246846e-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M609.75,123.0 L617.75,111.0 601.75,111.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-4b5ae123747f497d8b6871de1246846e-0-7" stroke-width="1px" d="M611,121.0 C611,81.0 689.5,81.0 689.5,121.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-4b5ae123747f497d8b6871de1246846e-0-7" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">flat:name</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M689.5,123.0 L697.5,111.0 681.5,111.0" fill="currentColor"/>
# </g>
# </svg></span>

# %%
get_sql_command([nlqs[16]])

# %%
doc = nlp(nlqs[16]) 
options = {'compact': False, 'word_spacing': 35, 'distance': 80, 'arrow_spacing': 1, 'arrow_stroke': 1} 
displacy.render(doc, style='dep', options=options)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="pt" id="95c0812d17f946ad99ea3baab0d01172-0" class="displacy" width="530" height="226.0" direction="ltr" style="max-width: none; height: 226.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="156.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">devolva</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="156.0">
#     <tspan class="displacy-word" fill="currentColor" x="130">quantos</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="130">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="156.0">
#     <tspan class="displacy-word" fill="currentColor" x="210">casos</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="210">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="156.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">há</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="156.0">
#     <tspan class="displacy-word" fill="currentColor" x="370">por</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="370">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="156.0">
#     <tspan class="displacy-word" fill="currentColor" x="450">município</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="450">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-95c0812d17f946ad99ea3baab0d01172-0-0" stroke-width="1px" d="M131,121.0 C131,81.0 209.5,81.0 209.5,121.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-95c0812d17f946ad99ea3baab0d01172-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M131,123.0 L123,111.0 139,111.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-95c0812d17f946ad99ea3baab0d01172-0-1" stroke-width="1px" d="M51,121.0 C51,41.0 209.75,41.0 209.75,121.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-95c0812d17f946ad99ea3baab0d01172-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">obj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M209.75,123.0 L217.75,111.0 201.75,111.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-95c0812d17f946ad99ea3baab0d01172-0-2" stroke-width="1px" d="M51,121.0 C51,1.0 290.0,1.0 290.0,121.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-95c0812d17f946ad99ea3baab0d01172-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">advcl</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M290.0,123.0 L298.0,111.0 282.0,111.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-95c0812d17f946ad99ea3baab0d01172-0-3" stroke-width="1px" d="M371,121.0 C371,81.0 449.5,81.0 449.5,121.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-95c0812d17f946ad99ea3baab0d01172-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">case</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M371,123.0 L363,111.0 379,111.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-95c0812d17f946ad99ea3baab0d01172-0-4" stroke-width="1px" d="M291,121.0 C291,41.0 449.75,41.0 449.75,121.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-95c0812d17f946ad99ea3baab0d01172-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">obl</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M449.75,123.0 L457.75,111.0 441.75,111.0" fill="currentColor"/>
# </g>
# </svg></span>

# %%
get_sql_command([nlqs[17]])

# %%
doc = nlp(nlqs[17]) 
options = {'compact': False, 'word_spacing': 35, 'distance': 80, 'arrow_spacing': 1, 'arrow_stroke': 1} 
displacy.render(doc, style='dep', options=options)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="pt" id="9b80fd88f48d4a40952fcf3e45ebd1b5-0" class="displacy" width="530" height="266.0" direction="ltr" style="max-width: none; height: 266.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="196.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">devolva</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="196.0">
#     <tspan class="displacy-word" fill="currentColor" x="130">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="130">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="196.0">
#     <tspan class="displacy-word" fill="currentColor" x="210">máxima</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="210">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="196.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">idade</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="196.0">
#     <tspan class="displacy-word" fill="currentColor" x="370">por</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="370">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="196.0">
#     <tspan class="displacy-word" fill="currentColor" x="450">município</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="450">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-9b80fd88f48d4a40952fcf3e45ebd1b5-0-0" stroke-width="1px" d="M131,161.0 C131,81.0 289.5,81.0 289.5,161.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-9b80fd88f48d4a40952fcf3e45ebd1b5-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M131,163.0 L123,151.0 139,151.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-9b80fd88f48d4a40952fcf3e45ebd1b5-0-1" stroke-width="1px" d="M211,161.0 C211,121.0 289.25,121.0 289.25,161.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-9b80fd88f48d4a40952fcf3e45ebd1b5-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M211,163.0 L203,151.0 219,151.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-9b80fd88f48d4a40952fcf3e45ebd1b5-0-2" stroke-width="1px" d="M51,161.0 C51,41.0 289.75,41.0 289.75,161.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-9b80fd88f48d4a40952fcf3e45ebd1b5-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">obj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M289.75,163.0 L297.75,151.0 281.75,151.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-9b80fd88f48d4a40952fcf3e45ebd1b5-0-3" stroke-width="1px" d="M371,161.0 C371,121.0 449.25,121.0 449.25,161.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-9b80fd88f48d4a40952fcf3e45ebd1b5-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">case</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M371,163.0 L363,151.0 379,151.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-9b80fd88f48d4a40952fcf3e45ebd1b5-0-4" stroke-width="1px" d="M51,161.0 C51,1.0 450.0,1.0 450.0,161.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-9b80fd88f48d4a40952fcf3e45ebd1b5-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">obl</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M450.0,163.0 L458.0,151.0 442.0,151.0" fill="currentColor"/>
# </g>
# </svg></span>

# %%
get_sql_command([nlqs[18]])

# %%
doc = nlp(nlqs[18]) 
options = {'compact': False, 'word_spacing': 35, 'distance': 80, 'arrow_spacing': 1, 'arrow_stroke': 1} 
displacy.render(doc, style='dep', options=options)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="pt" id="77dd61fefd174974b3f264aa1d2182a9-0" class="displacy" width="530" height="266.0" direction="ltr" style="max-width: none; height: 266.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="196.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">devolva</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="196.0">
#     <tspan class="displacy-word" fill="currentColor" x="130">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="130">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="196.0">
#     <tspan class="displacy-word" fill="currentColor" x="210">mínima</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="210">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="196.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">idade</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="196.0">
#     <tspan class="displacy-word" fill="currentColor" x="370">por</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="370">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="196.0">
#     <tspan class="displacy-word" fill="currentColor" x="450">município</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="450">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-77dd61fefd174974b3f264aa1d2182a9-0-0" stroke-width="1px" d="M131,161.0 C131,81.0 289.5,81.0 289.5,161.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-77dd61fefd174974b3f264aa1d2182a9-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">case</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M131,163.0 L123,151.0 139,151.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-77dd61fefd174974b3f264aa1d2182a9-0-1" stroke-width="1px" d="M211,161.0 C211,121.0 289.25,121.0 289.25,161.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-77dd61fefd174974b3f264aa1d2182a9-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M211,163.0 L203,151.0 219,151.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-77dd61fefd174974b3f264aa1d2182a9-0-2" stroke-width="1px" d="M51,161.0 C51,41.0 289.75,41.0 289.75,161.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-77dd61fefd174974b3f264aa1d2182a9-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">obj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M289.75,163.0 L297.75,151.0 281.75,151.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-77dd61fefd174974b3f264aa1d2182a9-0-3" stroke-width="1px" d="M371,161.0 C371,121.0 449.25,121.0 449.25,161.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-77dd61fefd174974b3f264aa1d2182a9-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">case</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M371,163.0 L363,151.0 379,151.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-77dd61fefd174974b3f264aa1d2182a9-0-4" stroke-width="1px" d="M51,161.0 C51,1.0 450.0,1.0 450.0,161.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-77dd61fefd174974b3f264aa1d2182a9-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">obl</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M450.0,163.0 L458.0,151.0 442.0,151.0" fill="currentColor"/>
# </g>
# </svg></span>

# %%
get_sql_command([nlqs[19]])

# %%
doc = nlp(nlqs[19]) 
options = {'compact': False, 'word_spacing': 35, 'distance': 80, 'arrow_spacing': 1, 'arrow_stroke': 1} 
displacy.render(doc, style='dep', options=options)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="pt" id="0ad4807d495a4e9984affc52831eafea-0" class="displacy" width="530" height="186.0" direction="ltr" style="max-width: none; height: 186.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="116.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">devolva</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="116.0">
#     <tspan class="displacy-word" fill="currentColor" x="130">as</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="130">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="116.0">
#     <tspan class="displacy-word" fill="currentColor" x="210">idades</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="210">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="116.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">somadas</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="116.0">
#     <tspan class="displacy-word" fill="currentColor" x="370">por</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="370">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="116.0">
#     <tspan class="displacy-word" fill="currentColor" x="450">município</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="450">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0ad4807d495a4e9984affc52831eafea-0-0" stroke-width="1px" d="M131,81.0 C131,41.0 209.75,41.0 209.75,81.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0ad4807d495a4e9984affc52831eafea-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M131,83.0 L123,71.0 139,71.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0ad4807d495a4e9984affc52831eafea-0-1" stroke-width="1px" d="M51,81.0 C51,1.0 210.0,1.0 210.0,81.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0ad4807d495a4e9984affc52831eafea-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">obj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M210.0,83.0 L218.0,71.0 202.0,71.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0ad4807d495a4e9984affc52831eafea-0-2" stroke-width="1px" d="M211,81.0 C211,41.0 289.75,41.0 289.75,81.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0ad4807d495a4e9984affc52831eafea-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">acl</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M289.75,83.0 L297.75,71.0 281.75,71.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0ad4807d495a4e9984affc52831eafea-0-3" stroke-width="1px" d="M371,81.0 C371,41.0 449.75,41.0 449.75,81.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0ad4807d495a4e9984affc52831eafea-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">case</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M371,83.0 L363,71.0 379,71.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0ad4807d495a4e9984affc52831eafea-0-4" stroke-width="1px" d="M291,81.0 C291,1.0 450.0,1.0 450.0,81.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0ad4807d495a4e9984affc52831eafea-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">obl</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M450.0,83.0 L458.0,71.0 442.0,71.0" fill="currentColor"/>
# </g>
# </svg></span>

# %%
get_sql_command([nlqs[20]])

# %%
doc = nlp(nlqs[20]) 
options = {'compact': False, 'word_spacing': 35, 'distance': 80, 'arrow_spacing': 1, 'arrow_stroke': 1} 
displacy.render(doc, style='dep', options=options)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="pt" id="66cdffa57f0e4b10b792b27b02354064-0" class="displacy" width="530" height="226.0" direction="ltr" style="max-width: none; height: 226.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="156.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">devolva</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="156.0">
#     <tspan class="displacy-word" fill="currentColor" x="130">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="130">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="156.0">
#     <tspan class="displacy-word" fill="currentColor" x="210">idade</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="210">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="156.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">média</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="156.0">
#     <tspan class="displacy-word" fill="currentColor" x="370">por</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="370">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="156.0">
#     <tspan class="displacy-word" fill="currentColor" x="450">município</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="450">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-66cdffa57f0e4b10b792b27b02354064-0-0" stroke-width="1px" d="M131,121.0 C131,81.0 209.5,81.0 209.5,121.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-66cdffa57f0e4b10b792b27b02354064-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M131,123.0 L123,111.0 139,111.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-66cdffa57f0e4b10b792b27b02354064-0-1" stroke-width="1px" d="M51,121.0 C51,41.0 209.75,41.0 209.75,121.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-66cdffa57f0e4b10b792b27b02354064-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">obj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M209.75,123.0 L217.75,111.0 201.75,111.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-66cdffa57f0e4b10b792b27b02354064-0-2" stroke-width="1px" d="M211,121.0 C211,81.0 289.5,81.0 289.5,121.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-66cdffa57f0e4b10b792b27b02354064-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M289.5,123.0 L297.5,111.0 281.5,111.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-66cdffa57f0e4b10b792b27b02354064-0-3" stroke-width="1px" d="M371,121.0 C371,81.0 449.5,81.0 449.5,121.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-66cdffa57f0e4b10b792b27b02354064-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">case</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M371,123.0 L363,111.0 379,111.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-66cdffa57f0e4b10b792b27b02354064-0-4" stroke-width="1px" d="M51,121.0 C51,1.0 450.0,1.0 450.0,121.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-66cdffa57f0e4b10b792b27b02354064-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">obl</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M450.0,123.0 L458.0,111.0 442.0,111.0" fill="currentColor"/>
# </g>
# </svg></span>

# %%
get_sql_command([nlqs[21]])

# %%
doc = nlp(nlqs[21]) 
options = {'compact': False, 'word_spacing': 35, 'distance': 80, 'arrow_spacing': 1, 'arrow_stroke': 1} 
displacy.render(doc, style='dep', options=options)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="pt" id="a6a7751457ad4738902d83e1e929452d-0" class="displacy" width="1170" height="226.0" direction="ltr" style="max-width: none; height: 226.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="156.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">devolva</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="156.0">
#     <tspan class="displacy-word" fill="currentColor" x="130">quantos</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="130">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="156.0">
#     <tspan class="displacy-word" fill="currentColor" x="210">óbitos</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="210">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="156.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">do</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="156.0">
#     <tspan class="displacy-word" fill="currentColor" x="370">tipo</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="370">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="156.0">
#     <tspan class="displacy-word" fill="currentColor" x="450">positivo</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="450">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="156.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">há</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="156.0">
#     <tspan class="displacy-word" fill="currentColor" x="610">no</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="610">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="156.0">
#     <tspan class="displacy-word" fill="currentColor" x="690">município</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="690">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="156.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">de</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="156.0">
#     <tspan class="displacy-word" fill="currentColor" x="850">São</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="850">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="156.0">
#     <tspan class="displacy-word" fill="currentColor" x="930">Paulo</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="930">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="156.0">
#     <tspan class="displacy-word" fill="currentColor" x="1010">por</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1010">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="156.0">
#     <tspan class="displacy-word" fill="currentColor" x="1090">raça</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1090">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-a6a7751457ad4738902d83e1e929452d-0-0" stroke-width="1px" d="M131,121.0 C131,81.0 209.5,81.0 209.5,121.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-a6a7751457ad4738902d83e1e929452d-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M131,123.0 L123,111.0 139,111.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-a6a7751457ad4738902d83e1e929452d-0-1" stroke-width="1px" d="M51,121.0 C51,41.0 209.75,41.0 209.75,121.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-a6a7751457ad4738902d83e1e929452d-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">obj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M209.75,123.0 L217.75,111.0 201.75,111.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-a6a7751457ad4738902d83e1e929452d-0-2" stroke-width="1px" d="M291,121.0 C291,81.0 369.5,81.0 369.5,121.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-a6a7751457ad4738902d83e1e929452d-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">case</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M291,123.0 L283,111.0 299,111.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-a6a7751457ad4738902d83e1e929452d-0-3" stroke-width="1px" d="M211,121.0 C211,41.0 369.75,41.0 369.75,121.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-a6a7751457ad4738902d83e1e929452d-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M369.75,123.0 L377.75,111.0 361.75,111.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-a6a7751457ad4738902d83e1e929452d-0-4" stroke-width="1px" d="M371,121.0 C371,81.0 449.5,81.0 449.5,121.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-a6a7751457ad4738902d83e1e929452d-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M449.5,123.0 L457.5,111.0 441.5,111.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-a6a7751457ad4738902d83e1e929452d-0-5" stroke-width="1px" d="M51,121.0 C51,1.0 530.0,1.0 530.0,121.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-a6a7751457ad4738902d83e1e929452d-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">advcl</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M530.0,123.0 L538.0,111.0 522.0,111.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-a6a7751457ad4738902d83e1e929452d-0-6" stroke-width="1px" d="M611,121.0 C611,81.0 689.5,81.0 689.5,121.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-a6a7751457ad4738902d83e1e929452d-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">case</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M611,123.0 L603,111.0 619,111.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-a6a7751457ad4738902d83e1e929452d-0-7" stroke-width="1px" d="M531,121.0 C531,41.0

# %%
get_sql_command([nlqs[22]])

# %%
doc = nlp(nlqs[22]) 
options = {'compact': False, 'word_spacing': 35, 'distance': 80, 'arrow_spacing': 1, 'arrow_stroke': 1} 
displacy.render(doc, style='dep', options=options)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="pt" id="f54f5dd481434027bf9ccad6804354b6-0" class="displacy" width="930" height="306.0" direction="ltr" style="max-width: none; height: 306.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="236.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">devolva</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="236.0">
#     <tspan class="displacy-word" fill="currentColor" x="130">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="130">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="236.0">
#     <tspan class="displacy-word" fill="currentColor" x="210">máxima</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="210">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="236.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">idade</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="236.0">
#     <tspan class="displacy-word" fill="currentColor" x="370">no</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="370">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="236.0">
#     <tspan class="displacy-word" fill="currentColor" x="450">município</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="450">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="236.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">de</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="236.0">
#     <tspan class="displacy-word" fill="currentColor" x="610">São</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="610">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="236.0">
#     <tspan class="displacy-word" fill="currentColor" x="690">Paulo</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="690">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="236.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">por</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="236.0">
#     <tspan class="displacy-word" fill="currentColor" x="850">raça</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="850">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-f54f5dd481434027bf9ccad6804354b6-0-0" stroke-width="1px" d="M131,201.0 C131,121.0 289.25,121.0 289.25,201.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-f54f5dd481434027bf9ccad6804354b6-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M131,203.0 L123,191.0 139,191.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-f54f5dd481434027bf9ccad6804354b6-0-1" stroke-width="1px" d="M211,201.0 C211,161.0 289.0,161.0 289.0,201.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-f54f5dd481434027bf9ccad6804354b6-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M211,203.0 L203,191.0 219,191.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-f54f5dd481434027bf9ccad6804354b6-0-2" stroke-width="1px" d="M51,201.0 C51,81.0 289.5,81.0 289.5,201.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-f54f5dd481434027bf9ccad6804354b6-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">obj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M289.5,203.0 L297.5,191.0 281.5,191.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-f54f5dd481434027bf9ccad6804354b6-0-3" stroke-width="1px" d="M371,201.0 C371,161.0 449.0,161.0 449.0,201.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-f54f5dd481434027bf9ccad6804354b6-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">case</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M371,203.0 L363,191.0 379,191.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-f54f5dd481434027bf9ccad6804354b6-0-4" stroke-width="1px" d="M51,201.0 C51,41.0 449.75,41.0 449.75,201.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-f54f5dd481434027bf9ccad6804354b6-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">obl</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M449.75,203.0 L457.75,191.0 441.75,191.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-f54f5dd481434027bf9ccad6804354b6-0-5" stroke-width="1px" d="M531,201.0 C531,161.0 609.0,161.0 609.0,201.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-f54f5dd481434027bf9ccad6804354b6-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">case</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M531,203.0 L523,191.0 539,191.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-f54f5dd481434027bf9ccad6804354b6-0-6" stroke-width="1px" d="M451,201.0 C451,121.0 609.25,121.0 609.25,201.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-f54f5dd481434027bf9ccad6804354b6-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M609.25,203.0 L617.25,191.0 601.25,191.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-f54f5dd481434027bf9ccad6804354b6-0-7" stroke-width="1px" d="M611,201.0 C611,161.0 689.0,161.0 689.0,201.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-f54f5dd481434027bf9ccad6804354b6-0-7" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">flat:name</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M689.0,203.0 L697.0,191.0 681.0,191.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-f54f5dd481434027bf9ccad6804354b6-0-8" stroke-width="1px" d="M771,201.0 C771,161.0 849.0,161.0 849.0,201.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xli

# %%
get_sql_command([nlqs[23]])

# %%
doc = nlp(nlqs[23]) 
options = {'compact': False, 'word_spacing': 35, 'distance': 80, 'arrow_spacing': 1, 'arrow_stroke': 1} 
displacy.render(doc, style='dep', options=options)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="pt" id="9ddedaf0151842ffbb6eaffa8f5e9375-0" class="displacy" width="930" height="306.0" direction="ltr" style="max-width: none; height: 306.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="236.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">devolva</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="236.0">
#     <tspan class="displacy-word" fill="currentColor" x="130">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="130">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="236.0">
#     <tspan class="displacy-word" fill="currentColor" x="210">mínima</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="210">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="236.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">idade</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="236.0">
#     <tspan class="displacy-word" fill="currentColor" x="370">no</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="370">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="236.0">
#     <tspan class="displacy-word" fill="currentColor" x="450">município</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="450">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="236.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">de</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="236.0">
#     <tspan class="displacy-word" fill="currentColor" x="610">São</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="610">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="236.0">
#     <tspan class="displacy-word" fill="currentColor" x="690">Paulo</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="690">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="236.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">por</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="236.0">
#     <tspan class="displacy-word" fill="currentColor" x="850">raça</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="850">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-9ddedaf0151842ffbb6eaffa8f5e9375-0-0" stroke-width="1px" d="M131,201.0 C131,121.0 289.25,121.0 289.25,201.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-9ddedaf0151842ffbb6eaffa8f5e9375-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">case</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M131,203.0 L123,191.0 139,191.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-9ddedaf0151842ffbb6eaffa8f5e9375-0-1" stroke-width="1px" d="M211,201.0 C211,161.0 289.0,161.0 289.0,201.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-9ddedaf0151842ffbb6eaffa8f5e9375-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M211,203.0 L203,191.0 219,191.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-9ddedaf0151842ffbb6eaffa8f5e9375-0-2" stroke-width="1px" d="M51,201.0 C51,81.0 289.5,81.0 289.5,201.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-9ddedaf0151842ffbb6eaffa8f5e9375-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">obj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M289.5,203.0 L297.5,191.0 281.5,191.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-9ddedaf0151842ffbb6eaffa8f5e9375-0-3" stroke-width="1px" d="M371,201.0 C371,161.0 449.0,161.0 449.0,201.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-9ddedaf0151842ffbb6eaffa8f5e9375-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">case</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M371,203.0 L363,191.0 379,191.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-9ddedaf0151842ffbb6eaffa8f5e9375-0-4" stroke-width="1px" d="M51,201.0 C51,41.0 449.75,41.0 449.75,201.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-9ddedaf0151842ffbb6eaffa8f5e9375-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">obl</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M449.75,203.0 L457.75,191.0 441.75,191.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-9ddedaf0151842ffbb6eaffa8f5e9375-0-5" stroke-width="1px" d="M531,201.0 C531,161.0 609.0,161.0 609.0,201.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-9ddedaf0151842ffbb6eaffa8f5e9375-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">case</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M531,203.0 L523,191.0 539,191.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-9ddedaf0151842ffbb6eaffa8f5e9375-0-6" stroke-width="1px" d="M451,201.0 C451,121.0 609.25,121.0 609.25,201.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-9ddedaf0151842ffbb6eaffa8f5e9375-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M609.25,203.0 L617.25,191.0 601.25,191.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-9ddedaf0151842ffbb6eaffa8f5e9375-0-7" stroke-width="1px" d="M611,201.0 C611,161.0 689.0,161.0 689.0,201.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-9ddedaf0151842ffbb6eaffa8f5e9375-0-7" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">flat:name</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M689.0,203.0 L697.0,191.0 681.0,191.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-9ddedaf0151842ffbb6eaffa8f5e9375-0-8" stroke-width="1px" d="M771,201.0 C771,161.0 849.0,161.0 849.0,201.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xl

# %%
get_sql_command([nlqs[24]])

# %%
doc = nlp(nlqs[24]) 
options = {'compact': False, 'word_spacing': 35, 'distance': 80, 'arrow_spacing': 1, 'arrow_stroke': 1} 
displacy.render(doc, style='dep', options=options)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="pt" id="722b1872ae584e679faf1048b6d50b99-0" class="displacy" width="930" height="226.0" direction="ltr" style="max-width: none; height: 226.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="156.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">devolva</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="156.0">
#     <tspan class="displacy-word" fill="currentColor" x="130">as</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="130">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="156.0">
#     <tspan class="displacy-word" fill="currentColor" x="210">idades</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="210">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="156.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">somadas</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="156.0">
#     <tspan class="displacy-word" fill="currentColor" x="370">no</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="370">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="156.0">
#     <tspan class="displacy-word" fill="currentColor" x="450">município</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="450">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="156.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">de</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="156.0">
#     <tspan class="displacy-word" fill="currentColor" x="610">São</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="610">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="156.0">
#     <tspan class="displacy-word" fill="currentColor" x="690">Paulo</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="690">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="156.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">por</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="156.0">
#     <tspan class="displacy-word" fill="currentColor" x="850">raça</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="850">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-722b1872ae584e679faf1048b6d50b99-0-0" stroke-width="1px" d="M131,121.0 C131,81.0 209.5,81.0 209.5,121.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-722b1872ae584e679faf1048b6d50b99-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M131,123.0 L123,111.0 139,111.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-722b1872ae584e679faf1048b6d50b99-0-1" stroke-width="1px" d="M51,121.0 C51,41.0 209.75,41.0 209.75,121.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-722b1872ae584e679faf1048b6d50b99-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">obj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M209.75,123.0 L217.75,111.0 201.75,111.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-722b1872ae584e679faf1048b6d50b99-0-2" stroke-width="1px" d="M211,121.0 C211,81.0 289.5,81.0 289.5,121.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-722b1872ae584e679faf1048b6d50b99-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">acl</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M289.5,123.0 L297.5,111.0 281.5,111.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-722b1872ae584e679faf1048b6d50b99-0-3" stroke-width="1px" d="M371,121.0 C371,81.0 449.5,81.0 449.5,121.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-722b1872ae584e679faf1048b6d50b99-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">case</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M371,123.0 L363,111.0 379,111.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-722b1872ae584e679faf1048b6d50b99-0-4" stroke-width="1px" d="M291,121.0 C291,41.0 449.75,41.0 449.75,121.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-722b1872ae584e679faf1048b6d50b99-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">obl</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M449.75,123.0 L457.75,111.0 441.75,111.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-722b1872ae584e679faf1048b6d50b99-0-5" stroke-width="1px" d="M531,121.0 C531,81.0 609.5,81.0 609.5,121.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-722b1872ae584e679faf1048b6d50b99-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">case</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M531,123.0 L523,111.0 539,111.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-722b1872ae584e679faf1048b6d50b99-0-6" stroke-width="1px" d="M451,121.0 C451,41.0 609.75,41.0 609.75,121.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-722b1872ae584e679faf1048b6d50b99-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M609.75,123.0 L617.75,111.0 601.75,111.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-722b1872ae584e679faf1048b6d50b99-0-7" stroke-width="1px" d="M611,121.0 C611,81.0 689.5,81.0 689.5,121.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-722b1872ae584e679faf1048b6d50b99-0-7" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">flat:name</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M689.5,123.0 L697.5,111.0 681.5,111.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-722b1872ae584e679faf1048b6d50b99-0-8" stroke-width="1px" d="M771,121.0 C771,81.0 849.5,81.0 849.5,121.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xli

# %%
get_sql_command([nlqs[25]])

# %%
doc = nlp(nlqs[25]) 
options = {'compact': False, 'word_spacing': 35, 'distance': 80, 'arrow_spacing': 1, 'arrow_stroke': 1} 
displacy.render(doc, style='dep', options=options)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="pt" id="785b0b6330204dae9deef98505d050f4-0" class="displacy" width="930" height="266.0" direction="ltr" style="max-width: none; height: 266.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="196.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">devolva</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="196.0">
#     <tspan class="displacy-word" fill="currentColor" x="130">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="130">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="196.0">
#     <tspan class="displacy-word" fill="currentColor" x="210">idade</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="210">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="196.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">média</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="196.0">
#     <tspan class="displacy-word" fill="currentColor" x="370">no</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="370">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="196.0">
#     <tspan class="displacy-word" fill="currentColor" x="450">município</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="450">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="196.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">de</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="196.0">
#     <tspan class="displacy-word" fill="currentColor" x="610">São</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="610">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="196.0">
#     <tspan class="displacy-word" fill="currentColor" x="690">Paulo</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="690">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="196.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">por</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="196.0">
#     <tspan class="displacy-word" fill="currentColor" x="850">raça</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="850">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-785b0b6330204dae9deef98505d050f4-0-0" stroke-width="1px" d="M131,161.0 C131,121.0 209.25,121.0 209.25,161.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-785b0b6330204dae9deef98505d050f4-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M131,163.0 L123,151.0 139,151.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-785b0b6330204dae9deef98505d050f4-0-1" stroke-width="1px" d="M51,161.0 C51,81.0 209.5,81.0 209.5,161.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-785b0b6330204dae9deef98505d050f4-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">obj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M209.5,163.0 L217.5,151.0 201.5,151.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-785b0b6330204dae9deef98505d050f4-0-2" stroke-width="1px" d="M211,161.0 C211,121.0 289.25,121.0 289.25,161.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-785b0b6330204dae9deef98505d050f4-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M289.25,163.0 L297.25,151.0 281.25,151.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-785b0b6330204dae9deef98505d050f4-0-3" stroke-width="1px" d="M371,161.0 C371,121.0 449.25,121.0 449.25,161.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-785b0b6330204dae9deef98505d050f4-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">case</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M371,163.0 L363,151.0 379,151.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-785b0b6330204dae9deef98505d050f4-0-4" stroke-width="1px" d="M51,161.0 C51,41.0 449.75,41.0 449.75,161.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-785b0b6330204dae9deef98505d050f4-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">obl</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M449.75,163.0 L457.75,151.0 441.75,151.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-785b0b6330204dae9deef98505d050f4-0-5" stroke-width="1px" d="M531,161.0 C531,121.0 609.25,121.0 609.25,161.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-785b0b6330204dae9deef98505d050f4-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">case</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M531,163.0 L523,151.0 539,151.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-785b0b6330204dae9deef98505d050f4-0-6" stroke-width="1px" d="M451,161.0 C451,81.0 609.5,81.0 609.5,161.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-785b0b6330204dae9deef98505d050f4-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M609.5,163.0 L617.5,151.0 601.5,151.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-785b0b6330204dae9deef98505d050f4-0-7" stroke-width="1px" d="M611,161.0 C611,121.0 689.25,121.0 689.25,161.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-785b0b6330204dae9deef98505d050f4-0-7" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">flat:name</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M689.25,163.0 L697.25,151.0 681.25,151.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-785b0b6330204dae9deef98505d050f4-0-8" stroke-width="1px" d="M771,161.0 C771,121.0 849.25,121.0 849.25,161.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">

# %%
get_sql_command([nlqs[26]])

# %%
doc = nlp(nlqs[26]) 
options = {'compact': False, 'word_spacing': 35, 'distance': 80, 'arrow_spacing': 1, 'arrow_stroke': 1} 
displacy.render(doc, style='dep', options=options)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="pt" id="9fadcaa3029c4173a88eb89d3f4f201d-0" class="displacy" width="1170" height="226.0" direction="ltr" style="max-width: none; height: 226.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="156.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">devolva</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="156.0">
#     <tspan class="displacy-word" fill="currentColor" x="130">quantos</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="130">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="156.0">
#     <tspan class="displacy-word" fill="currentColor" x="210">óbitos</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="210">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="156.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">do</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="156.0">
#     <tspan class="displacy-word" fill="currentColor" x="370">tipo</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="370">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="156.0">
#     <tspan class="displacy-word" fill="currentColor" x="450">positivo</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="450">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="156.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">há</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="156.0">
#     <tspan class="displacy-word" fill="currentColor" x="610">no</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="610">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="156.0">
#     <tspan class="displacy-word" fill="currentColor" x="690">município</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="690">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="156.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">de</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="156.0">
#     <tspan class="displacy-word" fill="currentColor" x="850">São</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="850">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="156.0">
#     <tspan class="displacy-word" fill="currentColor" x="930">Paulo</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="930">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="156.0">
#     <tspan class="displacy-word" fill="currentColor" x="1010">por</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1010">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="156.0">
#     <tspan class="displacy-word" fill="currentColor" x="1090">diagnóstico</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1090">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-9fadcaa3029c4173a88eb89d3f4f201d-0-0" stroke-width="1px" d="M131,121.0 C131,81.0 209.5,81.0 209.5,121.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-9fadcaa3029c4173a88eb89d3f4f201d-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M131,123.0 L123,111.0 139,111.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-9fadcaa3029c4173a88eb89d3f4f201d-0-1" stroke-width="1px" d="M51,121.0 C51,41.0 209.75,41.0 209.75,121.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-9fadcaa3029c4173a88eb89d3f4f201d-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">obj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M209.75,123.0 L217.75,111.0 201.75,111.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-9fadcaa3029c4173a88eb89d3f4f201d-0-2" stroke-width="1px" d="M291,121.0 C291,81.0 369.5,81.0 369.5,121.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-9fadcaa3029c4173a88eb89d3f4f201d-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">case</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M291,123.0 L283,111.0 299,111.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-9fadcaa3029c4173a88eb89d3f4f201d-0-3" stroke-width="1px" d="M211,121.0 C211,41.0 369.75,41.0 369.75,121.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-9fadcaa3029c4173a88eb89d3f4f201d-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M369.75,123.0 L377.75,111.0 361.75,111.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-9fadcaa3029c4173a88eb89d3f4f201d-0-4" stroke-width="1px" d="M371,121.0 C371,81.0 449.5,81.0 449.5,121.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-9fadcaa3029c4173a88eb89d3f4f201d-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M449.5,123.0 L457.5,111.0 441.5,111.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-9fadcaa3029c4173a88eb89d3f4f201d-0-5" stroke-width="1px" d="M51,121.0 C51,1.0 530.0,1.0 530.0,121.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-9fadcaa3029c4173a88eb89d3f4f201d-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">advcl</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M530.0,123.0 L538.0,111.0 522.0,111.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-9fadcaa3029c4173a88eb89d3f4f201d-0-6" stroke-width="1px" d="M611,121.0 C611,81.0 689.5,81.0 689.5,121.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-9fadcaa3029c4173a88eb89d3f4f201d-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">case</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M611,123.0 L603,111.0 619,111.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-9fadcaa3029c4173a88eb89d3f4f201d-0-7" stroke-width="1px" d="M531,121.0 C53

# %%
get_sql_command([nlqs[27]])

# %%
doc = nlp(nlqs[27]) 
options = {'compact': False, 'word_spacing': 35, 'distance': 80, 'arrow_spacing': 1, 'arrow_stroke': 1} 
displacy.render(doc, style='dep', options=options)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="pt" id="768bcf5fcee94b6ca54c8219b33c1e16-0" class="displacy" width="1090" height="266.0" direction="ltr" style="max-width: none; height: 266.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="196.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">devolva</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="196.0">
#     <tspan class="displacy-word" fill="currentColor" x="130">quantos</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="130">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="196.0">
#     <tspan class="displacy-word" fill="currentColor" x="210">diagnóstico</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="210">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="196.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">há</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="196.0">
#     <tspan class="displacy-word" fill="currentColor" x="370">agrupados</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="370">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="196.0">
#     <tspan class="displacy-word" fill="currentColor" x="450">por</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="450">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="196.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">raça</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="196.0">
#     <tspan class="displacy-word" fill="currentColor" x="610">e</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="610">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="196.0">
#     <tspan class="displacy-word" fill="currentColor" x="690">por</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="690">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="196.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">sexo</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="196.0">
#     <tspan class="displacy-word" fill="currentColor" x="850">e</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="850">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="196.0">
#     <tspan class="displacy-word" fill="currentColor" x="930">por</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="930">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="196.0">
#     <tspan class="displacy-word" fill="currentColor" x="1010">diagnóstico</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1010">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-768bcf5fcee94b6ca54c8219b33c1e16-0-0" stroke-width="1px" d="M131,161.0 C131,121.0 209.25,121.0 209.25,161.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-768bcf5fcee94b6ca54c8219b33c1e16-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M131,163.0 L123,151.0 139,151.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-768bcf5fcee94b6ca54c8219b33c1e16-0-1" stroke-width="1px" d="M51,161.0 C51,81.0 209.5,81.0 209.5,161.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-768bcf5fcee94b6ca54c8219b33c1e16-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">obj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M209.5,163.0 L217.5,151.0 201.5,151.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-768bcf5fcee94b6ca54c8219b33c1e16-0-2" stroke-width="1px" d="M51,161.0 C51,41.0 289.75,41.0 289.75,161.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-768bcf5fcee94b6ca54c8219b33c1e16-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">advcl</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M289.75,163.0 L297.75,151.0 281.75,151.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-768bcf5fcee94b6ca54c8219b33c1e16-0-3" stroke-width="1px" d="M51,161.0 C51,1.0 370.0,1.0 370.0,161.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-768bcf5fcee94b6ca54c8219b33c1e16-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">obj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M370.0,163.0 L378.0,151.0 362.0,151.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-768bcf5fcee94b6ca54c8219b33c1e16-0-4" stroke-width="1px" d="M451,161.0 C451,121.0 529.25,121.0 529.25,161.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-768bcf5fcee94b6ca54c8219b33c1e16-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">case</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M451,163.0 L443,151.0 459,151.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-768bcf5fcee94b6ca54c8219b33c1e16-0-5" stroke-width="1px" d="M371,161.0 C371,81.0 529.5,81.0 529.5,161.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-768bcf5fcee94b6ca54c8219b33c1e16-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">obl</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M529.5,163.0 L537.5,151.0 521.5,151.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-768bcf5fcee94b6ca54c8219b33c1e16-0-6" stroke-width="1px" d="M611,161.0 C611,81.0 769.5,81.0 769.5,161.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-768bcf5fcee94b6ca54c8219b33c1e16-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">cc</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M611,163.0 L603,151.0 619,151.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-768bcf5fcee94b6ca54c8219b33c1e16-0-7" stroke-width="1px" d="M691,161.0 C691,121.0 769.25,121.0 769.25,161.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-768bcf5fcee94b6ca54c8219b33c1e16-0-7" class="displacy-label" startOffset=

# %%
get_sql_command([nlqs[28]])

# %%
doc = nlp(nlqs[28]) 
options = {'compact': False, 'word_spacing': 35, 'distance': 80, 'arrow_spacing': 1, 'arrow_stroke': 1} 
displacy.render(doc, style='dep', options=options)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="pt" id="b3e0ebf3803b40caabf0f1c1f1c3bc86-0" class="displacy" width="930" height="306.0" direction="ltr" style="max-width: none; height: 306.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="236.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">devolva</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="236.0">
#     <tspan class="displacy-word" fill="currentColor" x="130">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="130">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="236.0">
#     <tspan class="displacy-word" fill="currentColor" x="210">máxima</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="210">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="236.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">idade</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="236.0">
#     <tspan class="displacy-word" fill="currentColor" x="370">no</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="370">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="236.0">
#     <tspan class="displacy-word" fill="currentColor" x="450">município</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="450">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="236.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">de</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="236.0">
#     <tspan class="displacy-word" fill="currentColor" x="610">São</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="610">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="236.0">
#     <tspan class="displacy-word" fill="currentColor" x="690">Paulo</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="690">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="236.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">por</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="236.0">
#     <tspan class="displacy-word" fill="currentColor" x="850">diagnóstico</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="850">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b3e0ebf3803b40caabf0f1c1f1c3bc86-0-0" stroke-width="1px" d="M131,201.0 C131,121.0 289.25,121.0 289.25,201.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b3e0ebf3803b40caabf0f1c1f1c3bc86-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M131,203.0 L123,191.0 139,191.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b3e0ebf3803b40caabf0f1c1f1c3bc86-0-1" stroke-width="1px" d="M211,201.0 C211,161.0 289.0,161.0 289.0,201.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b3e0ebf3803b40caabf0f1c1f1c3bc86-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M211,203.0 L203,191.0 219,191.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b3e0ebf3803b40caabf0f1c1f1c3bc86-0-2" stroke-width="1px" d="M51,201.0 C51,81.0 289.5,81.0 289.5,201.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b3e0ebf3803b40caabf0f1c1f1c3bc86-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">obj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M289.5,203.0 L297.5,191.0 281.5,191.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b3e0ebf3803b40caabf0f1c1f1c3bc86-0-3" stroke-width="1px" d="M371,201.0 C371,161.0 449.0,161.0 449.0,201.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b3e0ebf3803b40caabf0f1c1f1c3bc86-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">case</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M371,203.0 L363,191.0 379,191.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b3e0ebf3803b40caabf0f1c1f1c3bc86-0-4" stroke-width="1px" d="M51,201.0 C51,41.0 449.75,41.0 449.75,201.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b3e0ebf3803b40caabf0f1c1f1c3bc86-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">obl</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M449.75,203.0 L457.75,191.0 441.75,191.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b3e0ebf3803b40caabf0f1c1f1c3bc86-0-5" stroke-width="1px" d="M531,201.0 C531,161.0 609.0,161.0 609.0,201.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b3e0ebf3803b40caabf0f1c1f1c3bc86-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">case</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M531,203.0 L523,191.0 539,191.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b3e0ebf3803b40caabf0f1c1f1c3bc86-0-6" stroke-width="1px" d="M451,201.0 C451,121.0 609.25,121.0 609.25,201.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b3e0ebf3803b40caabf0f1c1f1c3bc86-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M609.25,203.0 L617.25,191.0 601.25,191.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b3e0ebf3803b40caabf0f1c1f1c3bc86-0-7" stroke-width="1px" d="M611,201.0 C611,161.0 689.0,161.0 689.0,201.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b3e0ebf3803b40caabf0f1c1f1c3bc86-0-7" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">flat:name</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M689.0,203.0 L697.0,191.0 681.0,191.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b3e0ebf3803b40caabf0f1c1f1c3bc86-0-8" stroke-width="1px" d="M771,201.0 C771,161.0 849.0,161.0 849.0,201.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textP

# %%
get_sql_command([nlqs[29]])

# %%
doc = nlp(nlqs[29]) 
options = {'compact': False, 'word_spacing': 35, 'distance': 80, 'arrow_spacing': 1, 'arrow_stroke': 1} 
displacy.render(doc, style='dep', options=options)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="pt" id="f3923eb0b38f43879d59c1a5c0158f00-0" class="displacy" width="930" height="306.0" direction="ltr" style="max-width: none; height: 306.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="236.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">devolva</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="236.0">
#     <tspan class="displacy-word" fill="currentColor" x="130">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="130">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="236.0">
#     <tspan class="displacy-word" fill="currentColor" x="210">mínima</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="210">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="236.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">idade</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="236.0">
#     <tspan class="displacy-word" fill="currentColor" x="370">no</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="370">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="236.0">
#     <tspan class="displacy-word" fill="currentColor" x="450">município</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="450">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="236.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">de</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="236.0">
#     <tspan class="displacy-word" fill="currentColor" x="610">São</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="610">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="236.0">
#     <tspan class="displacy-word" fill="currentColor" x="690">Paulo</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="690">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="236.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">por</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="236.0">
#     <tspan class="displacy-word" fill="currentColor" x="850">diagnóstico</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="850">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-f3923eb0b38f43879d59c1a5c0158f00-0-0" stroke-width="1px" d="M131,201.0 C131,121.0 289.25,121.0 289.25,201.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-f3923eb0b38f43879d59c1a5c0158f00-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">case</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M131,203.0 L123,191.0 139,191.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-f3923eb0b38f43879d59c1a5c0158f00-0-1" stroke-width="1px" d="M211,201.0 C211,161.0 289.0,161.0 289.0,201.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-f3923eb0b38f43879d59c1a5c0158f00-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M211,203.0 L203,191.0 219,191.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-f3923eb0b38f43879d59c1a5c0158f00-0-2" stroke-width="1px" d="M51,201.0 C51,81.0 289.5,81.0 289.5,201.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-f3923eb0b38f43879d59c1a5c0158f00-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">obj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M289.5,203.0 L297.5,191.0 281.5,191.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-f3923eb0b38f43879d59c1a5c0158f00-0-3" stroke-width="1px" d="M371,201.0 C371,161.0 449.0,161.0 449.0,201.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-f3923eb0b38f43879d59c1a5c0158f00-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">case</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M371,203.0 L363,191.0 379,191.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-f3923eb0b38f43879d59c1a5c0158f00-0-4" stroke-width="1px" d="M51,201.0 C51,41.0 449.75,41.0 449.75,201.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-f3923eb0b38f43879d59c1a5c0158f00-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">obl</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M449.75,203.0 L457.75,191.0 441.75,191.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-f3923eb0b38f43879d59c1a5c0158f00-0-5" stroke-width="1px" d="M531,201.0 C531,161.0 609.0,161.0 609.0,201.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-f3923eb0b38f43879d59c1a5c0158f00-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">case</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M531,203.0 L523,191.0 539,191.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-f3923eb0b38f43879d59c1a5c0158f00-0-6" stroke-width="1px" d="M451,201.0 C451,121.0 609.25,121.0 609.25,201.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-f3923eb0b38f43879d59c1a5c0158f00-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M609.25,203.0 L617.25,191.0 601.25,191.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-f3923eb0b38f43879d59c1a5c0158f00-0-7" stroke-width="1px" d="M611,201.0 C611,161.0 689.0,161.0 689.0,201.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-f3923eb0b38f43879d59c1a5c0158f00-0-7" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">flat:name</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M689.0,203.0 L697.0,191.0 681.0,191.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-f3923eb0b38f43879d59c1a5c0158f00-0-8" stroke-width="1px" d="M771,201.0 C771,161.0 849.0,161.0 849.0,201.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <text

# %%
get_sql_command([nlqs[30]])

# %%
doc = nlp(nlqs[30]) 
options = {'compact': False, 'word_spacing': 35, 'distance': 80, 'arrow_spacing': 1, 'arrow_stroke': 1} 
displacy.render(doc, style='dep', options=options)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="pt" id="4bc7e72592ab4fb698b00e0b541fbde5-0" class="displacy" width="930" height="226.0" direction="ltr" style="max-width: none; height: 226.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="156.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">devolva</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="156.0">
#     <tspan class="displacy-word" fill="currentColor" x="130">as</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="130">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="156.0">
#     <tspan class="displacy-word" fill="currentColor" x="210">idades</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="210">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="156.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">somadas</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="156.0">
#     <tspan class="displacy-word" fill="currentColor" x="370">no</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="370">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="156.0">
#     <tspan class="displacy-word" fill="currentColor" x="450">município</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="450">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="156.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">de</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="156.0">
#     <tspan class="displacy-word" fill="currentColor" x="610">São</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="610">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="156.0">
#     <tspan class="displacy-word" fill="currentColor" x="690">Paulo</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="690">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="156.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">por</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="156.0">
#     <tspan class="displacy-word" fill="currentColor" x="850">diagnóstico</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="850">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-4bc7e72592ab4fb698b00e0b541fbde5-0-0" stroke-width="1px" d="M131,121.0 C131,81.0 209.5,81.0 209.5,121.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-4bc7e72592ab4fb698b00e0b541fbde5-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M131,123.0 L123,111.0 139,111.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-4bc7e72592ab4fb698b00e0b541fbde5-0-1" stroke-width="1px" d="M51,121.0 C51,41.0 209.75,41.0 209.75,121.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-4bc7e72592ab4fb698b00e0b541fbde5-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">obj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M209.75,123.0 L217.75,111.0 201.75,111.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-4bc7e72592ab4fb698b00e0b541fbde5-0-2" stroke-width="1px" d="M211,121.0 C211,81.0 289.5,81.0 289.5,121.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-4bc7e72592ab4fb698b00e0b541fbde5-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">acl</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M289.5,123.0 L297.5,111.0 281.5,111.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-4bc7e72592ab4fb698b00e0b541fbde5-0-3" stroke-width="1px" d="M371,121.0 C371,81.0 449.5,81.0 449.5,121.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-4bc7e72592ab4fb698b00e0b541fbde5-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">case</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M371,123.0 L363,111.0 379,111.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-4bc7e72592ab4fb698b00e0b541fbde5-0-4" stroke-width="1px" d="M291,121.0 C291,41.0 449.75,41.0 449.75,121.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-4bc7e72592ab4fb698b00e0b541fbde5-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">obl</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M449.75,123.0 L457.75,111.0 441.75,111.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-4bc7e72592ab4fb698b00e0b541fbde5-0-5" stroke-width="1px" d="M531,121.0 C531,81.0 609.5,81.0 609.5,121.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-4bc7e72592ab4fb698b00e0b541fbde5-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">case</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M531,123.0 L523,111.0 539,111.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-4bc7e72592ab4fb698b00e0b541fbde5-0-6" stroke-width="1px" d="M451,121.0 C451,41.0 609.75,41.0 609.75,121.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-4bc7e72592ab4fb698b00e0b541fbde5-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M609.75,123.0 L617.75,111.0 601.75,111.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-4bc7e72592ab4fb698b00e0b541fbde5-0-7" stroke-width="1px" d="M611,121.0 C611,81.0 689.5,81.0 689.5,121.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-4bc7e72592ab4fb698b00e0b541fbde5-0-7" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">flat:name</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M689.5,123.0 L697.5,111.0 681.5,111.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-4bc7e72592ab4fb698b00e0b541fbde5-0-8" stroke-width="1px" d="M771,121.0 C771,81.0 849.5,81.0 849.5,121.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textP

# %%
get_sql_command([nlqs[31]])

# %%
doc = nlp(nlqs[31]) 
options = {'compact': False, 'word_spacing': 35, 'distance': 80, 'arrow_spacing': 1, 'arrow_stroke': 1} 
displacy.render(doc, style='dep', options=options)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="pt" id="37ed8aecd667449eb17591454f635add-0" class="displacy" width="930" height="266.0" direction="ltr" style="max-width: none; height: 266.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="196.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">devolva</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="196.0">
#     <tspan class="displacy-word" fill="currentColor" x="130">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="130">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="196.0">
#     <tspan class="displacy-word" fill="currentColor" x="210">idade</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="210">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="196.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">média</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="196.0">
#     <tspan class="displacy-word" fill="currentColor" x="370">no</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="370">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="196.0">
#     <tspan class="displacy-word" fill="currentColor" x="450">município</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="450">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="196.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">de</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="196.0">
#     <tspan class="displacy-word" fill="currentColor" x="610">São</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="610">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="196.0">
#     <tspan class="displacy-word" fill="currentColor" x="690">Paulo</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="690">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="196.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">por</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="196.0">
#     <tspan class="displacy-word" fill="currentColor" x="850">diagnóstico</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="850">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-37ed8aecd667449eb17591454f635add-0-0" stroke-width="1px" d="M131,161.0 C131,121.0 209.25,121.0 209.25,161.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-37ed8aecd667449eb17591454f635add-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M131,163.0 L123,151.0 139,151.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-37ed8aecd667449eb17591454f635add-0-1" stroke-width="1px" d="M51,161.0 C51,81.0 209.5,81.0 209.5,161.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-37ed8aecd667449eb17591454f635add-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">obj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M209.5,163.0 L217.5,151.0 201.5,151.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-37ed8aecd667449eb17591454f635add-0-2" stroke-width="1px" d="M211,161.0 C211,121.0 289.25,121.0 289.25,161.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-37ed8aecd667449eb17591454f635add-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M289.25,163.0 L297.25,151.0 281.25,151.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-37ed8aecd667449eb17591454f635add-0-3" stroke-width="1px" d="M371,161.0 C371,121.0 449.25,121.0 449.25,161.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-37ed8aecd667449eb17591454f635add-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">case</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M371,163.0 L363,151.0 379,151.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-37ed8aecd667449eb17591454f635add-0-4" stroke-width="1px" d="M51,161.0 C51,41.0 449.75,41.0 449.75,161.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-37ed8aecd667449eb17591454f635add-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">obl</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M449.75,163.0 L457.75,151.0 441.75,151.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-37ed8aecd667449eb17591454f635add-0-5" stroke-width="1px" d="M531,161.0 C531,121.0 609.25,121.0 609.25,161.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-37ed8aecd667449eb17591454f635add-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">case</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M531,163.0 L523,151.0 539,151.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-37ed8aecd667449eb17591454f635add-0-6" stroke-width="1px" d="M451,161.0 C451,81.0 609.5,81.0 609.5,161.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-37ed8aecd667449eb17591454f635add-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M609.5,163.0 L617.5,151.0 601.5,151.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-37ed8aecd667449eb17591454f635add-0-7" stroke-width="1px" d="M611,161.0 C611,121.0 689.25,121.0 689.25,161.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-37ed8aecd667449eb17591454f635add-0-7" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">flat:name</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M689.25,163.0 L697.25,151.0 681.25,151.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-37ed8aecd667449eb17591454f635add-0-8" stroke-width="1px" d="M771,161.0 C771,121.0 849.25,121.0 849.25,161.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
